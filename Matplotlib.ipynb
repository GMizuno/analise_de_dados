# %% [markdown]
# <h1>Matplotlib</h1>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Esse comando <b>%matplotlib</b> inline serve para mostrar o grafico no output

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x ** 2
print(f'Y é do tipo: {type(y)} \nX é do tipo: {type(x)}')
# Out:
# Y é do tipo: <class 'numpy.ndarray'>
# X é do tipo: <class 'numpy.ndarray'>

# %% [markdown]
# Forma mais rapida e simple de plotar um grafico, lembra o Matlab.

# %%
plt.plot(x, y)

# %% [markdown]
# Num IDE como Pycharm ou Spider para motrar o grafico basta usar plt.show

# %%
plt.plot(x, y, color = 'r') # Muda a cor 
plt.xlabel('Eixo X') # Muda nome do eixo  X
plt.xlabel('Eixo Y') # Muda nome do eixo  Y
plt.title('Titulo') # Muda nome do titulo
# Out:
# Text(0.5, 1.0, 'Titulo')

# %%
plt.plot(x, y, 'r--') # Muda a cor e coloca tracejado
plt.xlabel('Eixo X') # Muda nome do eixo  X
plt.xlabel('Eixo Y') # Muda nome do eixo  Y
plt.title('Titulo') # Muda nome do titulo
# Out:
# Text(0.5, 1.0, 'Titulo')

# %% [markdown]
# Plotando mais de um grafico no mesmo quadrado

# %%
plt.subplots(nrows = 1, ncols = 2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x11a7f0590>,
# ...
#        dtype=object))

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, color = 'g')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'r*--')

# %% [markdown]
# A proxima maneira de criar graficos com Matplotlib é a melhor forma, pois com ela usaremos Programação Orientada a Objeto e assim será possível acessar Atributos de Instâncias da Classe Matplotlib dando assim mais controle sobre o graficoe e permitindo a criação de ferramentas de edição.

# %%
fig = plt.figure()

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
fig = plt.figure()
axes = fig.add_axes([.1, .1, .8, .8])
axes.plot(x, y)
axes.set_xlabel('Eixo X')
axes.set_ylabel('Eixo Y')
axes.set_title('Titulo')
# Out:
# Text(0.5, 1.0, 'Titulo')

# %%
fig = plt.figure()
axes1 = fig.add_axes([.1, .1, .8, .8])
axes2 = fig.add_axes([.2, .5, .3, .3])
axes1.plot(x, y, 'g')
axes1.set_xlabel('Eixo X')
axes1.set_ylabel('Eixo Y')
axes1.set_title('Titulo')
axes2.plot(y, x, 'r')

# %%
fig = plt.figure()
axes1 = fig.add_axes([.1, .1, .8, .8])
axes1.plot(x, y)
axes1.set_xlabel('Eixo X')
axes1.set_ylabel('Eixo Y')
axes1.set_title('Titulo')
axes2 = fig.add_axes([.2, .5, .3, .3])
axes2.plot(y, x)
axes2.set_xlabel('Eixo X_2')
axes2.set_ylabel('Eixo Y_2')
axes2.set_title('Titulo_2')
# Out:
# Text(0.5, 1.0, 'Titulo_2')

# %% [markdown]
# <h2>Gerindo Eixos</h2>

# %%
fig, ax = plt.subplots()
ax

# %% [markdown]
# **Caso não entenda esse codigo ler comentaria abaixo**

# %%
fig, ax = plt.subplots()
ax.plot(x, x ** 3, 'b--')
ax.plot(x, x ** 4, 'g.--')
ax.set_xlabel('Eixo X')
ax.set_ylabel('Eixo Y')
ax.set_title('Titulo')
# Out:
# Text(0.5, 1.0, 'Titulo')

# %% [markdown]
# Para criar graficos com Matplotlib precisamos definir o espaço ocupado pela figura (fig) e criar seus eixos (ax). O codigo acima faz de maneira curta, mas não intutiva, essa criação de maneira rapida. Agoa vou mostrar a forma 'mais lenta'.

# %%
fig =  plt.figure(figsize = (12, 3)) # Criando figura sem eixo
fig = fig.add_subplot(1, 1, 1) # Coloquei eixos na figura

# %%
fig =  plt.figure(figsize = (12, 3)) # Criando figura sem eixo
fig = fig.add_subplot(1, 1, 1) # Coloquei eixos na figura
fig.plot(x, y, 'r-')
fig.plot(x, 2*y, 'b-')

# %% [markdown]
# Apesar de esse exemplo trabalhar somente com uma figura no subplot é bem intuitivo o que deve ser feito. Basta fazer alteração nos parametros 3 do subplot.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2)

# %%
ax
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11ae5c350>,
# ...
#       dtype=object)

# %% [markdown]
# Temos duas formas de criar graficos quando estamos no cenario anterior.
#
# Primeira forma, iterando.

# %%
for axe in ax:
    axe.plot(x, y, 'b')
    axe.set_xlabel('Eixo X')
    axe.set_ylabel('Eixo Y')
    axe.set_title('Titulo')
fig

# %% [markdown]
# Segunda forma, acessando valores do array.

# %%
ax[0].plot(x, y, 'b')
ax[0].set_xlabel('Eixo X')
ax[0].set_ylabel('Eixo Y')
ax[0].set_title('Titulo')

ax[1].plot(x, y, 'g')
ax[1].set_xlabel('Eixo X')
ax[1].set_ylabel('Eixo Y')
ax[1].set_title('Titulo')

fig

# %% [markdown]
# Agora supondo que queremos fazer um subplot com muitos graficos, com lidar com isso com as margens? Basta usar o método **.tight_layout()** que é responsável por 'ajeitar' as escalas.

# %%
fig, ax = plt.subplots(nrows = 5, ncols = 5)
plt.tight_layout()

# %% [markdown]
# Outra forma de lidar com a dimensão dos eixos

# %%
fig = plt.figure(figsize = (8, 4), dpi = 100)

# %% [markdown]
# Ainda não podemos ver essa figura pois não possui eixos!!!!

# %%
fig, axes = plt.subplots(figsize = (12, 3))
axes.plot(x, y, 'r-')

# %%
fig.savefig('Imagem.png')

# %%
fig, axes = plt.subplots(figsize = (12, 3))
axes.plot(x, y, 'r-')
axes.plot(x, 2*y, 'g*--')

# %% [markdown]
# Para criar legenda basta passar os label em nos plot

# %%
fig, axes = plt.subplots(figsize = (12, 3))
axes.plot(x, y, 'r-', label = 'x^2')
axes.plot(x, 2*y, 'g*--', label = 'Alguma coisa')
axes.legend()

# %% [markdown]
# Para mudar a posição da legenda basta passar o parametro loc, mas o Pyhton sempre tenta colocar na melhor possição.

# %%
fig, axes = plt.subplots(figsize = (12, 3))
axes.plot(x, y, 'r-', label = 'x^2')
axes.plot(x, 2*y, 'g*--', label = 'Alguma coisa')
axes.legend(loc = 1)

# %%
fig, axes = plt.subplots(figsize = (12, 3))
axes.plot(x, y, 'r-', label = 'x^2')
axes.plot(x, 2*y, 'g*--', label = 'Alguma coisa')
axes.legend(loc = 2)

# %%
fig, axes = plt.subplots(figsize = (12, 3))
axes.plot(x, y, 'r-', label = 'x^2')
axes.plot(x, 2*y, 'g*--', label = 'Alguma coisa')
axes.legend(loc = 3)

# %%
fig, axes = plt.subplots(figsize = (12, 3))
axes.plot(x, y, 'r-', label = 'x^2')
axes.plot(x, 2*y, 'g*--', label = 'Alguma coisa')
axes.legend(loc = 4)

# %%
fig, ax = plt.subplots()

lines = []
styles = ['-', '--', '-.', ':']
x = np.linspace(0, 10, 1000)

for i in range(4):
    lines += ax.plot(x, np.sin(x - i * np.pi / 2),
                     styles[i], color='black')
ax.axis('equal')

ax.legend(lines[:2], ['line A', 'line B'],
          loc='upper right', frameon=False)

from matplotlib.legend import Legend
leg = Legend(ax, lines[2:], ['line C', 'line D'],
             loc='lower right', frameon=False)
ax.add_artist(leg);

# %% [markdown]
# <h2>Gerindo Layout</h2>

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(x, x ** 2)
ax.plot(x, x ** 3)

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(x, x ** 2, color = '#8B008B') # Hexadecimal
ax.plot(x, x ** 3, color = 'green') # string

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(x, x ** 2, color = '#8B008B', linewidth = 1) # Espessura
ax.plot(x, x ** 3, color = 'green', lw = 10) # Espessura

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(x, x ** 2, color = '#8B008B', alpha = 0.1) # Opacidade (entre 0 e 1)
ax.plot(x, x ** 3, color = 'green', alpha = 0.8) # Opacidade (entre 0 e 1)

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(x, x ** 2, linestyle = '-')
ax.plot(x, x ** 3, linestyle = '--')
ax.plot(x, x ** 4, linestyle = ':')

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(x, x ** 2, linestyle = '-', marker = '+') # Add marcador
ax.plot(x, x ** 3, linestyle = '-', marker = 'o') # Add marcador
ax.plot(x, x ** 4, linestyle = '-', marker = 's') # Add marcador

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(x, x ** 2, marker = '+', markeredgecolor ='red', markerfacecolor ='blue') # Add cor de entrono e dentro do marcador
ax.plot(x, x ** 3, marker = 'o', markeredgecolor ='blue', markerfacecolor = 'red') # Add cor de entrono e dentro do marcador
ax.plot(x, x ** 4, marker = 's', markeredgecolor ='green', markerfacecolor = 'pink') # Add cor de entrono e dentro do marcador

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.plot(x, x ** 2)
ax.plot(x, x ** 3)

ax.set_xlim([0,4]) # Mudando limite do eixo X
ax.set_ylim([0,90]) # Mudando limite do eixo y
# Out:
# (0, 90)

# %% [markdown]
# <h3>Grafico de Pontos</h3>

# %%
x = np.linspace(0, 5, 11)
y = x ** 2
plt.scatter(x,y)

# %%
plt.scatter(x,y, marker = 'o', edgecolors = 'red', color = 'green' )

# %% [markdown]
# <h2>Referencias Extras</h2>

# %% [markdown]
# * http://www.matplotlib.org - A página web do projeto matplotlib.
# * https://github.com/matplotlib/matplotlib - O código fonte de matplotlib.
# * http://matplotlib.org/gallery.html - Uma grande galeria mostrando diversos tipos de gráficos que Matplotlib pode criar. Altamente recomendado!
# * http://www.loria.fr/~rougier/teaching/matplotlib - Um excelente tutorial sobre a biblioteca.
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html -  Outra excelente referência no asssunto.
